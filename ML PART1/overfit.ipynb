# %% [markdown]
# ###### BIAS- error from wrong adjumtion
# ###### VARIENCE-sensitivity to small data changes

# %% [markdown]
# ## Over Fitting
#
# #### Thats mean our model is too complex, Thats mean training accuracy is very high and thetesting  accuraccy is very low
# 1. low bias
# 2. high varience
#
# 1. WE dicrease the model complexity
# 2. decrese the nurons
# 3. decrese the leyers
# 4. regularization increse
# 5. add more data does help

# %% [markdown]
# ## Under Fitting
# #### Thats mean the model is to simple ,and the training ND test acccuracy both are low
# 1. high bias
# 2. low varience
#
# #### problem solve
# 1. we increase the model complexity
# 2. increse the no of layers
# 3. increse the no of
# 4. regularization decrese
# 5. no of features increse
# 6. no extra data helps

# %% [markdown]
# ## Optimal model
# #### A model that have a balance accuracy in both side of test and train
#
# 1. low bias
# 2. low varience
#
# thats solve by the bias-varience-tradeof
