# %%
import pandas as pd
import seaborn as sns

# %%
insurance=pd.read_csv("insurance.csv") 
insurance

# %%
sns.scatterplot(x=insurance["bmi"],y=insurance["charges"],hue=insurance["smoker"])

# %%
# we do the feature engeenearing for better performance
# we remove the regionn avlues because it contains multi type of input

X=insurance.drop(columns=["charges","region"])  #we put the independent values here
y=insurance["charges"] #we put the dependent values here


X["sex"]=X["sex"].map({"female":1,"male":0})  #we chamge the data values into maths values using the map
# female=1, or male =0

X["smoker"]=X["smoker"].map({"yes":1,"no":0})

# %%
X.head()

# %%
# split into two parts

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Split into two parts
#
# #### Thats mean -  train_test_split
# 1. the data is devided into two parts using model_selection
# 2. One for trainning that use the machine learning
# 3. Secondd is test data that use later for testing our model

# %%
X_train.head()

# %%
X_test.head()

# %%
# train our model

from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,y_train)

# %% [markdown]
# # Train our Model
# 1. we use the sklearn library (sklearn.linear_model)  LinearRegression
# 2. model.fit(X_train,y_train)

# %%
# predict values using the predict function
y_pred=model.predict(X_test)

# %%
y_test

# %%
y_pred

# %%
# EVALUATE
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
print(r2)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
print("r_squred :" ,r2)

n=X_test.shape[0]
p=X_test.shape[1]

adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
print("adjusted r^2 :",adjusted_r2)

# %%
X_test.shape

# %%
# ONe Hot Encoding

X=insurance.drop(columns=["charges"])  
y=insurance["charges"] 

X=pd.get_dummies(X,columns=["region"],drop_first=True,dtype=int)

X["sex"]=X["sex"].map({"female":1,"male":0})  
# female=1, or male =0

X["smoker"]=X["smoker"].map({"yes":1,"no":0})

# %%
X.head()

# %%
# split into two parts

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# train our model

from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

# EVALUATE
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
print(r2)

from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
print("r_squred :" ,r2)

n=X_test.shape[0]
p=X_test.shape[1]

adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
print("adjusted r^2 :",adjusted_r2)

# %%
# FEATURE ENGENEARING

X=insurance.drop(columns=["charges"])  
y=insurance["charges"] 

# ONe Hot Encoding
X=pd.get_dummies(X,columns=["region"],drop_first=True,dtype=int)

X["sex"]=X["sex"].map({"female":1,"male":0})  
# female=1, or male =0

X["smoker"]=X["smoker"].map({"yes":1,"no":0})

# INTERACTION FEATURES
X["age_smoker"]=X["age"]* X["smoker"]
X["bmi_smoker"]=X["bmi"]*X["smoker"]

# %%
# split into two parts

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# train our model

from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

# EVALUATE

from sklearn.metrics import r2_score

r2_test=r2_score(y_test,y_pred)
print("r_squred :" ,r2_test)

n=X_test.shape[0]
p=X_test.shape[1]

adjusted_r2=1-((1-r2_test)*(n-1)/(n-p-1))
print("adjusted r^2 :",adjusted_r2)

# %%
# underfit and overfit
# r2 training is low and r2 testing is also low- underfit
# r2 training   >>> r2 testing  overerfit

y_train_pred=model.predict(X_train)
r2_train= r2_score(y_train,y_train_pred)

print("the training r2 value is :",r2_train)
print("the testing r2 value is :",r2_test)

# %%
insurance.shape
